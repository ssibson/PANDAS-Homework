# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
Path.cwd()
# Out:
# PosixPath('/Users/killermac/Desktop/PANDAS-Homework/Starter-Files')

# %%
# Setting file paths
whale_data = Path("../Starter-Files/whale_returns.csv")
algo_data = Path("../Starter-Files/algo_returns.csv")
sp500_data = Path("../Starter-Files/sp500_history.csv")

# Reading the CSVs and setting the `date` column as a datetime index to the DataFrame
whale_df = pd.read_csv(whale_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_df = pd.read_csv(algo_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_df = pd.read_csv(sp500_data, index_col="Date", infer_datetime_format=True, parse_dates=True)

# %%
#Reading Whale Data

whale_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
# Checking for NaNs within whales data

whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Cleaning nulls from whales by dropping

whale_df = whale_df.dropna().copy()
whale_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
# Checking removal of NaNs from whales

whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
#Reading algo data
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
# Checking for NaNs within algo data

algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Cleaning nulls from algo_df by dropping

algo_df = algo_df.dropna().copy()
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %%
# Checking removal of NaNs from algo data

algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
#Reading S&P 500 data
sp500_df
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06
# ...              ...
# 2012-10-05  $1460.93
# 2012-10-04  $1461.40
# 2012-10-03  $1450.99
# 2012-10-02  $1445.75
# 2012-10-01  $1444.49
#
# [1649 rows x 1 columns]

# %%
# Retrieving S&P 500 data types

sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Cleaning '$' From Close Price
sp500_df['Close'] = sp500_df['Close'].str.replace('$','')
sp500_df['Close']
# Out:
# Date
# 2019-04-23    2933.68
# 2019-04-22    2907.97
# 2019-04-18    2905.03
# 2019-04-17    2900.45
# 2019-04-16    2907.06
#                ...
# 2012-10-05    1460.93
# 2012-10-04    1461.40
# 2012-10-03    1450.99
# 2012-10-02    1445.75
# 2012-10-01    1444.49
# Name: Close, Length: 1649, dtype: object

# %%
# Checking Close data type
sp500_df['Close'].dtype
# Out:
# dtype('O')

# %%
# Casting Close Series as a Float
sp500_df['Close'] = sp500_df['Close'].astype('float')
sp500_df['Close'].dtype
# Out:
# dtype('float64')

# %%
# Confirming Data type Fix

sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Sorting dataframe in ascending
sp500_df.sort_index(inplace=True)

# %%
# Calculate the daily return using the 'shift()' function
daily_returns = (sp500_df - sp500_df.shift(1)) / sp500_df.shift(1)
daily_returns
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1649 rows x 1 columns]

# %%
# Cleaning nulls from daily returns by dropping

daily_returns = daily_returns.dropna().copy()
daily_returns
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
#Rename 'Close' Column to 'S&P 500'
daily_returns.columns = ['S&P 500']
daily_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
sp500_df
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93
# ...             ...
# 2019-04-16  2907.06
# 2019-04-17  2900.45
# 2019-04-18  2905.03
# 2019-04-22  2907.97
# 2019-04-23  2933.68
#
# [1649 rows x 1 columns]

# %%
# Concatenating all DataFrames to one
combined_df = pd.concat([whale_df, algo_df, daily_returns], axis="columns", join="inner")
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %%
##### PORTFOLIO ANALYSIS #####

# %%
# Plot daily returns

combined_df.plot(figsize=(20, 10), title='Daily Returns')

# %%
# Using the `cumprod` function to calculate cumulative returns

cumulative_returns = (1 + combined_df).cumprod()
cumulative_returns.plot(figsize=(20, 10), title='Cumulative Returns')

# %%
# Visualizing data risk via Box Plot

combined_df.plot.box(figsize=(20, 10), title='Portfolio Risk')

# %%
# Daily Standard Deviations

daily_std = combined_df.std()
daily_std.head(7)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
# Identifying the portfolio with the most risk

daily_std = daily_std.sort_values(ascending=False)
daily_std.head(7)
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# S&P 500                        0.008554
# Algo 2                         0.008342
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 1                         0.007620
# PAULSON & CO.INC.              0.007023
# dtype: float64

# %%
# Determining which portfolios are riskier than the S&P 500
sp500risk = daily_std.loc['S&P 500']
daily_std > sp500risk
# Out:
# BERKSHIRE HATHAWAY INC          True
# TIGER GLOBAL MANAGEMENT LLC     True
# S&P 500                        False
# Algo 2                         False
# SOROS FUND MANAGEMENT LLC      False
# Algo 1                         False
# PAULSON & CO.INC.              False
# dtype: bool

# %%
# Calculating the annualized standard deviation
annualized_std = daily_std * np.sqrt(252)
annualized_std.head(7)
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P 500                        0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %%
##### ROLLING STATISTICS #####

# %%
# Calc and plot 21-Day Rolling Standard Deviation

combined_df.rolling(window=21).std().plot(figsize = (20, 10), title = '21-Day Rolling Standard Deviation')

# %%
# Constructing a correlation table (with Pearson Method)

correlation = combined_df.corr(method="pearson")
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
BHI_covariance=combined_df['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(combined_df["S&P 500"])
variance=combined_df["S&P 500"].rolling(60).var()
(BHI_covariance/variance).plot(figsize=(20,10),title="Berkshire Hathaway Inc. Beta")

#BHI_covariance = combined_df['BERKSHIRE HATHAWAY INC'].cov(combined_df['S&P 500'])
#variance = combined_df['S&P 500'].var()
#BHI_beta = BHI_covariance / variancefd
#BHI_rolling = combined_df['BERKSHIRE HATHAWAY INC'].rolling(21).cov(combined_df['S&P 500'])
#BHI_rolling.plot(figsize=(20, 10), title='Berkshire Hathaway Inc. Beta')

# %%
# Calculating and plotting a rolling window using the exponentially weighted moving average. 

combined_df.ewm(halflife=21).std().plot(figsize=(20, 10), title = 'Exponentially Weighted Average')

# %%
# Calculating annualized Sharpe Ratios

sharpe_ratios = (combined_df.mean() * 252) / (daily_std * np.sqrt(252))
sharpe_ratios
# Out:
# Algo 1                         1.378648
# Algo 2                         0.501364
# BERKSHIRE HATHAWAY INC         0.621810
# PAULSON & CO.INC.             -0.483570
# S&P 500                        0.648267
# SOROS FUND MANAGEMENT LLC      0.356417
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# dtype: float64

# %%
# Visualizing the sharpe ratios as a bar plot

sharpe_ratios.plot.bar(figsize = (20, 10), title = 'Sharpe Ratios')

# %%
#####On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:

#    Algo 1 far outperforms all of the whales and the S&P 500. 
#    Algo 2 is outperformed by Berkshire Hathaway and 
#    the S&P 500, while still outperforming Soros, Tiger Global
#    and Paulson & Co.

# %%
##### Portfolio Returns #####

# %%
# READING IN FFIV Stock
FFIV_data = Path("../Starter-Files/FFIV_Data.csv")
ffiv_df = pd.read_csv(FFIV_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
ffiv_df.head()
# Out:
#              Close
# Date
# 2015-03-03  119.01
# 2015-03-04  119.24
# 2015-03-05  119.22
# 2015-03-06  117.96
# 2015-03-09  114.83

# %%
# READING IN COST Stock
COST_data = Path("../Starter-Files/COST_Data.csv")
cost_df = pd.read_csv(COST_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
cost_df.head()
# Out:
#              Close
# Date
# 2015-03-03  147.37
# 2015-03-04  147.17
# 2015-03-05  151.17
# 2015-03-06  149.54
# 2015-03-09  150.68

# %%
# READING IN PANW Stock
PANW_data = Path("../Starter-Files/PANW_data.csv")
panw_df = pd.read_csv(PANW_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
panw_df.head()
# Out:
#              Close
# Date
# 2015-03-03  148.90
# 2015-03-04  143.51
# 2015-03-05  143.14
# 2015-03-06  140.73
# 2015-03-09  138.73

# %%
# READING IN PYPL Stock
PYPL_data = Path("../Starter-Files/PYPL_data.csv")
pypl_df = pd.read_csv(PYPL_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
pypl_df.head()
# Out:
#             Close
# Date
# 2015-07-06  36.71
# 2015-07-07  36.62
# 2015-07-08  34.70
# 2015-07-09  34.50
# 2015-07-10  34.69

# %%
# Concatenate all stocks into a single DataFrame

combined_portfolio_df = pd.concat([cost_df, ffiv_df, panw_df, pypl_df], axis="columns", join="inner")
combined_portfolio_df.sort_index(inplace=True)
combined_portfolio_df.columns = ["COST", "FFIV", "PANW", "PYPL"]
combined_portfolio_df.head()
# Out:
#               COST    FFIV    PANW   PYPL
# Date
# 2015-07-06  135.88  117.55  175.32  36.71
# 2015-07-07  140.50  118.32  171.51  36.62
# 2015-07-08  139.90  117.84  172.48  34.70
# 2015-07-09  139.45  115.35  174.81  34.50
# 2015-07-10  142.72  116.39  180.80  34.69

# %%
# Sorting dataframe in ascending
combined_portfolio_df.sort_index(inplace=True)

# %%
# Calculate the daily return using the 'shift()' function
daily_pf_returns = (combined_portfolio_df - combined_portfolio_df.shift(1)) / combined_portfolio_df.shift(1)
daily_pf_returns
# Out:
#                 COST      FFIV      PANW      PYPL
# Date
# 2015-07-06       NaN       NaN       NaN       NaN
# 2015-07-07  0.034001  0.006550 -0.021732 -0.002452
# 2015-07-08 -0.004270 -0.004057  0.005656 -0.052430
# 2015-07-09 -0.003217 -0.021130  0.013509 -0.005764
# 2015-07-10  0.023449  0.009016  0.034266  0.005507
# ...              ...       ...       ...       ...
# 2019-04-24  0.009691  0.001830  0.008379  0.002993
# 2019-04-25 -0.009518 -0.010837  0.009666  0.027980
# 2019-04-26 -0.007248 -0.016003  0.001548  0.003085
# 2019-04-29  0.001887 -0.004816  0.013667  0.017004
# 2019-04-30  0.005117 -0.013828 -0.001485  0.002935
#
# [962 rows x 4 columns]

# %%
# Cleaning nulls from DataFrame by dropping
daily_pf_returns = daily_pf_returns.dropna().copy()
daily_pf_returns.head()
# Out:
#                 COST      FFIV      PANW      PYPL
# Date
# 2015-07-07  0.034001  0.006550 -0.021732 -0.002452
# 2015-07-08 -0.004270 -0.004057  0.005656 -0.052430
# 2015-07-09 -0.003217 -0.021130  0.013509 -0.005764
# 2015-07-10  0.023449  0.009016  0.034266  0.005507
# 2015-07-13  0.009389  0.005155  0.001825  0.060248

# %%
# Calculate weighted portfolio returns
weights = [1/4, 1/4, 1/4, 1/4]
portfolio_returns = daily_pf_returns.dot(weights)
portfolio_returns
# Out:
# Date
# 2015-07-07    0.004092
# 2015-07-08   -0.013775
# 2015-07-09   -0.004150
# 2015-07-10    0.018060
# 2015-07-13    0.019154
#                 ...
# 2019-04-24    0.005723
# 2019-04-25    0.004323
# 2019-04-26   -0.004654
# 2019-04-29    0.006935
# 2019-04-30   -0.001815
# Length: 961, dtype: float64

# %%
# Adding Custom Portfolio to earlier Combined DataFrame

final_df = pd.concat([whale_df, algo_df, daily_returns],axis="columns", join="inner")
final_df["Custom"] = portfolio_returns
final_df.sort_index(inplace=True)
final_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
# Cleaning nulls from combined DataFrame by dropping
final_df = final_df.dropna().copy()
final_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-07-07                   0.000597            0.003962
# 2015-07-08                  -0.017211           -0.007654
# 2015-07-09                   0.007472            0.003887
# 2015-07-10                   0.008969            0.003589
# 2015-07-13                   0.007946            0.001149
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-07-07                     0.004652               -0.007634 -0.004611
# 2015-07-08                    -0.014788               -0.011737 -0.013853
# 2015-07-09                     0.000441                0.017670  0.014090
# 2015-07-10                     0.013605                0.007015  0.003362
# 2015-07-13                     0.008658                0.010178  0.004215
#
#               Algo 2   S&P 500    Custom
# Date
# 2015-07-07 -0.002519  0.006081  0.004092
# 2015-07-08 -0.015528 -0.016653 -0.013775
# ...

# %%
# Assessing risk
final_volatility = final_df.std() * np.sqrt(252)
final_volatility.sort_values(inplace=True)
final_volatility
# Out:
# PAULSON & CO.INC.              0.115060
# Algo 1                         0.123379
# SOROS FUND MANAGEMENT LLC      0.128451
# Algo 2                         0.135252
# S&P 500                        0.137790
# TIGER GLOBAL MANAGEMENT LLC    0.178657
# Custom                         0.193540
# BERKSHIRE HATHAWAY INC         0.211795
# dtype: float64

# %%
# Calculating and plotting a rolling window using the exponentially weighted moving average. 

final_df.ewm(halflife=21).std().plot(figsize=(20, 10), title = '21-Day Rolling Standard Deviation')

# %%
# Calculating annualized Sharpe Ratios

final_sharpe_ratios = (final_df.mean() * 252) / (final_df.std() * np.sqrt(252))
final_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.374540
# PAULSON & CO.INC.             -0.594726
# TIGER GLOBAL MANAGEMENT LLC   -0.126606
# BERKSHIRE HATHAWAY INC         0.682010
# Algo 1                         1.499441
# Algo 2                         0.547964
# S&P 500                        0.737344
# Custom                         0.999793
# dtype: float64

# %%
# Visualizing the sharpe ratios as a bar plot

final_sharpe_ratios.plot.bar(figsize = (20, 10), title = 'Sharpe Ratios including Custom Portfolio')

# %%
# Constructing a final correlation table (with Pearson Method)

final_correlation = final_df.corr(method="pearson")
final_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699874
# PAULSON & CO.INC.                             0.699874            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.554362            0.428079
# BERKSHIRE HATHAWAY INC                        0.753733            0.543406
# Algo 1                                        0.326845            0.277709
# Algo 2                                        0.827389            0.679331
# S&P 500                                       0.839239            0.672557
# Custom                                        0.660208            0.513503
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.554362
# PAULSON & CO.INC.                               0.428079
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.416998
# ...

# %%
# Calculating and plotting Custom portfolio beta

final_covariance=final_df['Custom'].rolling(window=60).cov(final_df["S&P 500"])
final_variance=combined_df["S&P 500"].rolling(60).var()
(final_covariance/final_variance).plot(figsize=(20,10),title="Custom Portfolio Beta")

# %%
### How does your portfolio fair?:

# My custom portfolio containing stock from F5 Industries, 
# Costco, Palo Alto Networks Inc. and PayPal fared better
# than all but algorithm 1 when considering risk vs. return
